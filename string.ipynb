# %%
s = 'Its my world with lot of fun'

# %%
len(s)
# Out:
# 28

# %%
s.count('it')
# Out:
# 1

# %%
x = input('Enter a sentence: ')
print('converting sentence to uppercase: ', x.upper())
print('converting sentence to lowercase: ', x.lower())
# Out:
# Enter a sentence: anu is my name
# converting sentence to uppercase:  ANU IS MY NAME
# converting sentence to lowercase:  anu is my name

# %%
count = 0
for i in range(len(s)):
  if s[i]!=' ':
    count+=1
count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e55991e2860f> in <module>()
#       1
#       2 count = 0
# ----> 3 for i in range(len(s)):
#       4   if s[i]!=' ':
#       5     count+=1
#
# NameError: name 's' is not defined

# %%
import datetime
import math

print(math.sqrt(225))
print(math.factorial(9))
print(datetime.)
# Out:
# 15.0
# 362880
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-d6efed7c37c7> in <module>()
#       4 print(math.sqrt(225))
#       5 print(math.factorial(9))
# ----> 6 print(datetime.date())
#
# TypeError: function missing required argument 'year' (pos 1)

# %%
import array 
a = array.array('i', [1,2,3,4])
print(a)
# Out:
# array('i', [1, 2, 3, 4])

# %%
a.append(9)

# %%
print(a)
# Out:
# array('i', [1, 2, 3, 4, 9])

# %%
a.buffer_info()
# Out:
# (139748467679184, 5)

# %%
a.count(1)
# Out:
# 1

# %%
a.extend([1,2,3])

# %%
print(a)
# Out:
# array('i', [1, 2, 3, 4, 9, 1, 2, 3])

# %%
a.index(2)
# Out:
# 1

# %%
a.insert(2, 0)

# %%
print(a)
# Out:
# array('u', 'abcabc')

# %%
a = array.array('u',['a','b','c'])
b = ['a','b','c']

a.fromlist(b)

# %%
a
# Out:
# array('u', 'abcabc')

# %%
a.typecode
# Out:
# 'u'

# %%
v = array.array(a.typecode, (i for i in a))

# %%
v
# Out:
# array('u', 'abcabc')

# %%
for e in a:
  print(e)
# Out:
# a
# b
# c
# a
# b
# c

# %%
from array import *
arr = array('i', [])
num = int(input('Enter the length of an array: '))
i=0
while i < num:
  k = int(input('Enter next element to isert:  '))
  arr.append(k)
  
  i+=1
arr
# Out:
# Enter the length of an array: 4
# Enter next element to isert:  1
# Enter next element to isert:  2
# Enter next element to isert:  3
# Enter next element to isert:  4
# array('i', [1, 2, 3, 4])

# %%
val = int(input('Enter the element whose inndex to search: '))
for i in range(len(arr)):
  if val == arr[i]:
    print(i)
    break
# Out:
# Enter the element whose inndex to search: 3
# 2

# %%
arr.index()
