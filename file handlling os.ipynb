# %%
# #File handling is an important part of any web application.
# Python has several functions for creating, reading, updating, and deleting files.
# The key function for working with files in Python is the open() function.
# file_object = open("path/to/file",access_mode)
# f = open('new.text', 'r')
# f.read()
# r – read only
# r+ – read and write
# w – write only
# w+ – write and read
# a – append to existing data
# a+ – append and read

# %%
f = open('new.text', 'r')
f.readline()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-79-f48f3d1ee667> in <module>()
# ----> 1 f = open('new.text', 'r')
#       2 f.readline()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'new.text'

# %%
f = open('new.text', 'r+')
f.readlines()
f.write('I am moon')
f.read()

# %%
fd = open('new.text', 'r+')
fd.read()
fd.write(' michael')
fd.close()
fd = open('new.text', 'r+')
fd.read()

# %%
f1 = open('create.text', 'w+')
f1.write('Create me')
f1.write('go behind him')
f1.write('watch what is he doing')
f1.write('Your name')

f1.close()
f1 = open('create.txt', 'w+')
f1.read()

# %%
fp = open(r'/content/drive/MyDrive/new.txt', 'r')
print(fp.read())
fp.close()
# Out:
# I am doing goodppy to feel you
# thanks for the help

# %%
fp = open('/content/drive/MyDrive/new.txt', 'r')
print(fp.read())
fp.close()
# Out:
# I am doing goodppy to feel you
# thanks for the help

# %%
fp = open('/content/drive/MyDrive/new.txt', 'r+')
fp.write('I am doing good')
print(fp.read())
fp.close()
# Out:
# ppy to feel you
# thanks for the help

# %%
fp = open('/content/drive/MyDrive/new.txt', 'r')
print(fp.read())
fp.close()
# Out:
# I am doing goodppy to feel you
# thanks for the help

# %%
fp = open('text.txt', 'w')
fp.write('My name')
fp.write('My father')
fp.close()
fp = open('text.txt', 'r')
print(fp.read())
fp.close()

# %%
fp = open('file.txt', 'w+')
data: input('Enter your data: ')
fp.write(data)
fp.write('This is second')

fp.seek(14)
data = fp.read()
print(data)

# %%
with open('hey.txt') as fp:

  for line in fp:
    print(line)



#dbt how to print in each line

# %%
p = open('h.txt', 'w+')

p.writelines('cat\n')
p.writelines('rat\n')
p.writelines('sat\n')

p.seek(0)
print(p.readline())
print(p.readline())
print(p.readline())

# %%
with open('hey.txt', 'r+') as f:
  f.writelines('my world ')
  
  f.writelines('your place')
  f= read()

  for line in f:
    print(line.read(), end='')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-e208070371ca> in <module>()
#       5
#       6   for line in f:
# ----> 7     print(line.read(), end='')
#       8
#
# AttributeError: 'str' object has no attribute 'read'

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
os.chdir('')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-99-4c7b299520fb> in <module>()
# ----> 1 os.chdir('')
#
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %%
# listing subdir
os.listdir()
# Out:
# ['.config', 'file.txt', 'h.txt', 'hey.txt', 'drive', 'text.txt', 'sample_data']

# %%
os.mkdir('lolipop')

# %%
os.listdir()
# Out:
# ['.config',
#  'file.txt',
#  'h.txt',
#  'hey.txt',
#  'drive',
#  'text.txt',
#  'lolipop',
#  'sample_data']

# %%
os.rename('lolipop', 'cute')

# %%
os.listdir()
# Out:
# ['.config',
#  'file.txt',
#  'h.txt',
#  'hey.txt',
#  'cute',
#  'drive',
#  'text.txt',
#  'sample_data']

# %%
os.rmdir('cute')

# %%
os.listdir()
# Out:
# ['.config', 'file.txt', 'h.txt', 'hey.txt', 'drive', 'text.txt', 'sample_data']

# %%
os.mkdir('sweet')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-112-817b2d0bc465> in <module>()
#       1
# ----> 2 os.mkdir('sweet')
#
# FileExistsError: [Errno 17] File exists: 'sweet'

# %%
pip install shuttle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 40 kB 4.1 MB/s
# ...
#   Created wheel for shuttle: filename=shuttle-0.8-py3-none-any.whl size=11719 sha256=bd8e9cd827152c95a705c99eeaa1679314d87e0f5d2b0e5627ef247051130305
#   Stored in directory: /root/.cache/pip/wheels/23/10/7c/f6d473374a015155987bf35f25c8f543ae0f0fb50f4f225e02
# ...
#   Created wheel for deskapi: filename=deskapi-0.1-py3-none-any.whl size=7892 sha256=cb44ec6ca3b16b6fdb26607f30bc4ff71c03f6d158834a301293ea688644888c
#   Stored in directory: /root/.cache/pip/wheels/d9/71/c2/23b172c54a4998f7207dfd99c246e5398bf13415bf8bc7b201
# Successfully built shuttle deskapi
# ...

# %%
import shutil
shutil.rmtree('sweet')

# %%
os.listdir()
# Out:
# ['.config',
#  '.ipynb_checkpoints',
#  'file.txt',
#  'hey.txt',
#  'drive',
#  'text.txt',
#  'sample_data']

# %%
print(dir(locals()['__builtins__']))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EnvironmentError', 'Exception', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxWarning', 'SystemErr
# ...

# %%
import sys
li = ['a', 0,2]
for s in li:
  try:
    print(s)
    d = 1/int(s)
    break
  except:
    print(sys.exc_info()[0])
print(s)
# Out:
# a
# <class 'ValueError'>
# 0
# <class 'ZeroDivisionError'>
# 2
# 2
