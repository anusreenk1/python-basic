# %%
s = '#abc'
len(s)
# Out:
# 4

# %%
s.capitalize()
# Out:
# 'Sorry father   '

# %%
s.title()
# Out:
# 'Sorry Father   '

# %%
s.center(200)
# Out:
# '                                                                                            sorry father                                                                                                '

# %%
s.find(' ')
# Out:
# 5

# %%
s.format('a')
# Out:
# 'asorry father   '

# %%
a= {'x':'cat', 'y':'dog'}
s.format_map(a)
# Out:
# 'catdogsorry father   '

# %%
s.join(s)
# Out:
# 'aabcbabcc'

# %%
s.rjust(20)
# Out:
# '                 abc'

# %%
s.count('m')
# Out:
# 0

# %%
s.lstrip('a')
# Out:
# '#abc'

# %%
s.swapcase()
# Out:
# '#ABC'

# %%
s.index('d')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-b535aaa344ee> in <module>()
# ----> 1 s.index('d')
#
# ValueError: substring not found

# %%
s.rindex('c')
# Out:
# 3

# %%
s.zfill(5)
# Out:
# '0#abc'

# %%
li = [1,2,3,4]
li.
