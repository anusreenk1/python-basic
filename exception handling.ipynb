# %%
def calc():
  try:
    a = (int(i) for i in input('enter two numgbers: ').split())
    raise NameError('The input not defined')
    sum = a+b
    return sum
    
  except NameError as e:
    print(e)
  finally:
    print('process finished!!')
  


calc()
# Out:
# enter two numgbers: 10 5
# The input not defined
# process finished!!

# %%
class Calc:
  def __init__(self, a, b):
    self.a = a
    self.b = b

  def sum(self):
    sum = self.a +self.b
    return sum
try:
  m = Calc(6, 'a')
  m.c
except AttributeError as err:
  print(err)
# Out:
# 'Calc' object has no attribute 'c'

# %%
try:
  d = {1:'a', 2:2, 3:'b'}
  d[5]
  
except KeyError as e:
  print('its not a valid key')
# Out:
# its not a valid key

# %%
a = int(input('Enter a number: '))
for i in range(10):
 
  try:
    c= a/i
    if i == 0:
      raise ZeroDivisionError('it was a zero division')
    else:
      print(c)
  except ZeroDivisionError as err:
    print(err)
# Out:
# Enter a number: 10
# division by zero
# 10.0
# 5.0
# 3.3333333333333335
# 2.5
# 2.0
# 1.6666666666666667
# 1.4285714285714286
# 1.25
# 1.1111111111111112

# %%
li = [1,2,3,4]
try:
  li[6]
except IndexError as err:
  print(err)
# Out:
# list index out of range

# %%
p = float(input('enter principle amount: '))
t = int(input('Enter the time:')) 
r = float(input('enter the rate: '))
try:
  simple_interest = (p*t*r)/100
  if simple_interest > 100:
    raise Exception ('the simple interest is higher than normal')
  else:
    print(simple_interest)
except Exception as err:
  print(err)
# Out:
#   File "<ipython-input-3-7fbc238b98bb>", line 10
#     except Exception
#          ^
# SyntaxError: invalid syntax
