# %%
li = [1,2,3,4,5,6]
sum = 0
for i in range(len(li)):
  sum += li[i]
print(sum)
# Out:
# 21

# %%
#largest no:

print(max(li))
# Out:
# 6

# %%
#smallest no:
print(min(li))
# Out:
# 1

# %%
# check a list is empty or not
li = [1,2]
if len(li) == 0:
  print('list is empty')
else:
  print('list is not empty')
# Out:
# list is not empty

# %%
li = [1,2,3,4]
new_li = li.copy()
print(new_li)
# Out:
# [1, 2, 3, 4]

# %%
#access an element:
li[2]
# Out:
# 3

# %%
#access the index:
li.index(2)
# Out:
# 1

# %%
#append
age = []
name = ['john','bob','ben','loe']
for i in name:
  age.append(i)
print(age)
# Out:
# ['john', 'bob', 'ben', 'loe']

# %%
#unique values
li = [11, 11, 12, 12, 14, 13, 13]
se = set(li)
k =list(se)
print(k)
# Out:
# [11, 12, 13, 14]

# %%
#common item in list
li = [1,2,3,4,5]
li2 = [3,4,5,8,9]
k = set(li)&set(li2)
print(list(k))
# Out:
# [3, 4, 5]

# %%
#odd item
li[::2]
# Out:
# [1, 3, 5]

# %%
#concatinate
li3 = li+li2
print(li3)
# Out:
# [1, 2, 3, 4, 5, 3, 4, 5, 8, 9]

# %%
st = 'wonderful world'
li = list(st)
print(li)
# Out:
# ['w', 'o', 'n', 'd', 'e', 'r', 'f', 'u', 'l', ' ', 'w', 'o', 'r', 'l', 'd']

# %%
#extend
li = [1,2,3,4,5]
li2 = [3,4,5,8,9]
li.extend(li2)
li
# Out:
# [1, 2, 3, 4, 5, 3, 4, 5, 8, 9]
