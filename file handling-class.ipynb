# %%
f = open('/content/drive/MyDrive/new.txt','r')
print(f)
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/new.txt' mode='r' encoding='UTF-8'>

# %%
f.read()
# Out:
# 'H here I am'

# %%
f.close()

# %%
try:
  f = open('/content/drive/MyDrive/new.txt','r')
finally:
  f.close()

# %%
with open('/content/drive/MyDrive/new.txt','r') as f:
