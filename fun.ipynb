# %%
def name():
  a = input('Enter your name: ')
  print(a)
name()
# Out:
# Enter your name: anu
# anu

# %%
def great(a):
  print('Hello '+ a)
great('anu')
# Out:
# Hello anu

# %%
'''anuhhsdcj''' #docstring
# Out:
# 'anuhhsdcj'

# %%
def name():
  '''printing hello world'''
  print('Hello world')
name()
print(name.__doc__)
# Out:
# Hello world
# printing hello world

# %%
def value(a):
  if a >= 0:
    return a
  else:
    return -a
print(value(6))
print(value(-9))
# Out:
# 6
# 9

# %%
def val():
  s = 6
  print(s)
s = 10 #global
print(s)
val()
# Out:
# 10
# 6

# %%
def sum(a,b):
  sum = a+b
  print(sum)
sum(7,9)
# Out:
# 16

# %%
def sum(a,b):
  sum = a+b
  return sum
x = 1
y = 5
print(sum(x,y))
# Out:
# 6

# %%
def age(a, b=16):
  print(a,b)
age(6)
age(9, 13)
# Out:
# 6 16
# 9 13

# %%
def age(name, age):
  print(name, age)
age('anu', 30) # positional
age(name= 'kavya', age=12) # keyword argmnt
age(age=12, name= 'kavya')
age('jaya', age=15)
# Out:
# anu 30
# kavya 12
# kavya 12
# jaya 15

# %%
age(name = 'jaya',15)
# Out:
#   File "<ipython-input-17-d5499c8d939a>", line 1
#     age(name = 'jaya',15)
#                      ^
# SyntaxError: positional argument follows keyword argument

# %%
c = lambda a,b: a+b
print(c(6,5))
# Out:
# 11

# %%
li = [1,2,3,4]
c = list(filter(lambda x: (x%2 == 0), li))
print(c)
# Out:
# [2, 4]

# %%
li= [2,4,5,6,7]
a = list(map(lambda x:(x*2), li))
print(a)
# Out:
# [4, 8, 10, 12, 14]

# %%
def name():
  print('my name')
  name()
name()
# Out:
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# my name
# ...

# %%
a =10
def value():
  global a
  a = 6
  print(a)
value()
print(a)
# Out:
# 6
# 6

# %%
def calculation(a,b):
  sum = a+b
  sub = a-b
  return sum, sub

calculation(5,6)
# Out:
# (11, -1)

# %%
def employee(name, salary=9000):
  print(name, salary)

employee('joe', 10000)
employee('lee')
# Out:
# joe 10000
# lee 9000
