# %%
li = [] # null list
# append method
li = [1,2,'an','the']
li.append(0)
li
# Out:
# [1, 2, 'an', 'the', 0]

# %%
#sort
li= ['an','the','pop']
li.sort()
li
# Out:
# ['an', 'pop', 'the']

# %%
#sort
li = ['z', 'g', 'c', 'b']
li.sort() # return sort in ascending order default 
li
# Out:
# ['b', 'c', 'g', 'z']

# %%
li = [4,3,9,1,2]
li.sort(reverse = True)
li
# Out:
# [9, 4, 3, 2, 1]

# %%
li = [1,2,5,7]
lis = li
lis
# Out:
# [1, 2, 5, 7]

# %%
lis.append(3)
lis
# Out:
# [1, 2, 5, 7, 3]

# %%
li
# Out:
# [1, 2, 5, 7, 3]

# %%
li = ['b','a','n','a','n','a']
lis = li.copy()
lis
# Out:
# ['b', 'a', 'n', 'a', 'n', 'a']

# %%
lis.append(4)
lis
# Out:
# ['b', 'a', 'n', 'a', 'n', 'a', 4]

# %%
li
# Out:
# ['b', 'a', 'n', 'a', 'n', 'a', 3, 4, 5, 3, 4, 5]

# %%
li2 = [3,4,5]
li.extend(li2)
li
# Out:
# ['b', 'a', 'n', 'a', 'n', 'a', 3, 4, 5, 3, 4, 5, 3, 4, 5, 3, 4, 5]

# %%
li = [1,2,3,4,5]
li.count(2)
# Out:
# 1

# %%
li = [3,44,54,6]
li.reverse()
li
# Out:
# [6, 54, 44, 3]

# %%
li = [7,66,75,11]
li.insert(0,0)
.
li
# Out:
# [0, 7, 66, 75, 11]

# %%
li.pop(1)
li
# Out:
# [0, 11]

# %%
li = [3,4,6,7,8,0]
li.remove(0)
li
# Out:
# [3, 4, 6, 7, 8]
