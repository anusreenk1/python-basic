# %%
tup = () # null tuple
tup = (1,) #Sinle element tuple
tup
# Out:
# (1,)

# %%
tup = (1,2,3,'an','the')
tup.count(1)
# Out:
# 1

# %%
tup.index(2)
# Out:
# 1

# %%
tup[1]
# Out:
# 2

# %%
tup[1] = 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-73ead4fb8e3c> in <module>()
# ----> 1 tup[1] = 0
#
# TypeError: 'tuple' object does not support item assignment
